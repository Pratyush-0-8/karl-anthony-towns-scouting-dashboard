# %%
import pandas as pd 
from tqdm import tqdm
import time

# %%
from nba_api.stats.static import players
player_dict = players.get_players()
Flagg = [player for player in player_dict if player['full_name'] == 'Cooper Flagg'][0]
Flagg_id = Flagg['id']
from nba_api.stats.static import teams
team_dict = teams.get_teams()

# %%
from nba_api.stats.endpoints import playergamelog

Flagg_gamelog = playergamelog.PlayerGameLog(player_id = Flagg_id)

# %%
Flagg_gamelog_df = Flagg_gamelog.get_data_frames()[0]

# %%
Flagg_gamelog_df["Block_Stat"] = (Flagg_gamelog_df["BLK"] > 0).astype(int)
print(Flagg_gamelog_df.columns)
# Out:
# Index(['SEASON_ID', 'Player_ID', 'Game_ID', 'GAME_DATE', 'MATCHUP', 'WL',
#        'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA',
#        'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF',
#        'PTS', 'PLUS_MINUS', 'VIDEO_AVAILABLE', 'Block_Stat'],
#       dtype='object')
